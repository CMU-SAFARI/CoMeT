# %%
### READ RESULTS INTO PANDAS DATAFRAME
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

resultsdir = "../../../ae-results/"
# list all directories in resultsdir
#configs = [d for d in os.listdir(resultsdir) if os.path.isdir(os.path.join(resultsdir, d))]
configs = ['Baseline.yaml',
            "CoMeT1000-1-128-128.yaml",
            "CoMeT1000-1-256-128.yaml",
            "CoMeT1000-1-512-128.yaml",
            "CoMeT1000-1-1024-128.yaml",
            "CoMeT1000-1-2048-128.yaml",
            "CoMeT1000-2-128-128.yaml",
            "CoMeT1000-2-256-128.yaml",
            "CoMeT1000-2-512-128.yaml",
            "CoMeT1000-2-1024-128.yaml",
            "CoMeT1000-2-2048-128.yaml",
            "CoMeT1000-4-128-128.yaml",
            "CoMeT1000-4-256-128.yaml",
            "CoMeT1000-4-512-128.yaml",
            "CoMeT1000-4-1024-128.yaml",
            "CoMeT1000-4-2048-128.yaml",
            "CoMeT1000-8-128-128.yaml",
            "CoMeT1000-8-256-128.yaml",
            "CoMeT1000-8-512-128.yaml",
            "CoMeT1000-8-1024-128.yaml",
            "CoMeT1000-8-2048-128.yaml",
            "CoMeT1000-16-128-128.yaml",
            "CoMeT1000-16-256-128.yaml",
            "CoMeT1000-16-512-128.yaml",
            "CoMeT1000-16-1024-128.yaml",
            "CoMeT1000-16-2048-128.yaml",
        ]
#configs = ['Baseline.yaml', 'CMS1000-100.yaml', 'Graphene1000.yaml', 'CMS1000-100-c.yaml']
# print found configs
print('Found configs: {}'.format(configs))
# list all directories under all configs
workloads = []
for c in configs:
    workloads.append([d for d in os.listdir(os.path.join(resultsdir, c)) if os.path.isdir(os.path.join(resultsdir, c, d))])
# find only the intersection of all workloads
workloads = list(set.intersection(*map(set, workloads)))
# print found workloads
print('Found workloads: {}'.format(workloads))

stats_per_config_workload = []

# for every config + workload directory
for c in configs:
    for w in workloads:
        # find all files in the directory
        files = [f for f in os.listdir(os.path.join(resultsdir, c, w)) if os.path.isfile(os.path.join(resultsdir, c, w, f))]
        # find the stats file
        stat_files = [f for f in files if f.endswith('.stats')]
        # if there is a stats file
        if stat_files:
            for stat_file in stat_files:
                # if the stats_file has less than three lines skip it
                if len(open(os.path.join(resultsdir, c, w, stat_file)).readlines()) < 3:
                    continue
                
                # print the name of the stats_file
                print('Found stats file: {}'.format(os.path.join(os.path.join(resultsdir, c, w, stat_file))))

                extension = ''
                # if stats_file file name itself does not start with DDR4, parse it a bit
                if not stat_file.startswith('DDR4'):
                    # get the config name from the stats_file name
                    extension = '_'.join(stat_file.split('_')[:-1])
                    # prepend underscore to extension
                    extension = '_' + extension

                # read the stats file, name columns: 'name', 'value', 'description'
                df = pd.read_csv(os.path.join(resultsdir, c, w, stat_file), header=None).T
                df.columns = df.iloc[0]
                df.drop(0,inplace=True)
                # add a new column called 'config' with the config name
                df['config'] = c + extension
                # add a new column called 'workload' with the workload name
                df['workload'] = w
                # print the stats file
                # print('Config: {}, Workload: {}, Stats: {}'.format(c, w, df))
                # append the stats to the list
                df.reset_index(inplace=True, drop=True)
                stats_per_config_workload.append(df)
        else:
            print('Config: {}, Workload: {}, Stats: No stats file found'.format(c, w))

# concatenate all stats into one dataframe
stats = pd.concat(stats_per_config_workload)

# find elements where workload does not contain '-'
# these are multi core workloads
stats = stats[~stats['workload'].str.contains('-')]

# remove these two workloads: stream_10.trace and random_10.trace
stats = stats[~stats['workload'].isin(['stream10_200.trace', 'random10_200.trace'])]
# also from workloads
workloads = [w for w in workloads if not w in ['stream10_200', 'random10_200.trace']]

#remove configs that has RH32, AH and AAH in the name
stats = stats[~stats['config'].str.contains('RH32')]
stats = stats[~stats['config'].str.contains('AH')]
stats = stats[~stats['config'].str.contains('AAH')]

# replace 'Baseline' with 'Baseline0'
stats['config'] = stats['config'].str.replace('ae-results/', '')
stats['config'] = stats['config'].str.replace('../results/', '')
stats['config'] = stats['config'].str.replace('Baseline', 'Baseline0')

# add a new column that stores in integer the number in the config name
stats['nrh'] = stats['config'].str.extract('(\d+)').astype(int)

# remove numbers from config names
stats['config'] = stats['config'].str.replace('\d+', '')

# remove yaml from config names
stats['config'] = stats['config'].str.replace('.yaml', '')

print(stats['workload'].unique())
stats_copy = stats.copy()
# Out:
# Found configs: ['Baseline.yaml', 'CoMeT1000-1-128-128.yaml', 'CoMeT1000-1-256-128.yaml', 'CoMeT1000-1-512-128.yaml', 'CoMeT1000-1-1024-128.yaml', 'CoMeT1000-1-2048-128.yaml', 'CoMeT1000-2-128-128.yaml', 'CoMeT1000-2-256-128.yaml', 'CoMeT1000-2-512-128.yaml', 'CoMeT1000-2-1024-128.yaml', 'CoMeT1000-2-2048-128.yaml', 'CoMeT1000-4-128-128.yaml', 'CoMeT1000-4-256-128.yaml', 'CoMeT1000-4-512-128.yaml', 'CoMeT1000-4-1024-128.yaml', 'CoMeT1000-4-2048-128.yaml', 'CoMeT1000-8-128-128.yaml', 'CoMeT1000-8-256-128.yaml', 'CoMeT1000-8-512-128.yaml', 'CoMeT1000-8-1024-128.yaml', 'CoMeT1000-8-2048-128.yaml', 'CoMeT1000-16-128-128.yaml', 'CoMeT1000-16-256-128.yaml', 'CoMeT1000-16-512-128.yaml', 'CoMeT1000-16-1024-128.yaml', 'CoMeT1000-16-2048-128.yaml']
# Found workloads: ['523.xalancbmk', 'ycsb_dserver', '510.parest', '541.leela', 'wc_8443', '459.GemsFDTD', '531.deepsjeng', 'bfs_cm2003', '450.soplex', '519.lbm', 'ycsb_abgsave', 'ycsb_aserver', '447.dealII', 'tpch17', '507.cactuBSSN', '444.namd', '520.omnetpp', 'ycsb_bserver', '435.gromacs', 'ycsb_eserver', '557.xz', '429.mcf', '445.gobmk', 'jp2_encode', '526.blender', '437.leslie3d', 'ycsb_cserver', '483.xalancbmk', '471.omnetpp', '462.libquantum', '458.sjeng', '500.perlbench', '525.x264', 'tpcc64', '511.povray', '401.bzip2', '473.astar', '538.imagick', 'bfs_ny', '434.zeusmp', 'h264_decode', '436.cactusADM', '508.namd', '481.wrf', '433.milc', '403.gcc', 'tpch6', 'wc_map0', 'grep_map0', '470.lbm', '544.nab', '549.fotonik3d', '482.sphinx3', '505.mcf', 'bfs_dblp', 'jp2_decode', 'h264_encode', '502.gcc', '464.h264ref', 'tpch2', '456.hmmer']
# Found stats file: ../../../verify-results/Baseline.yaml/523.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/ycsb_dserver/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/510.parest/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/541.leela/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/wc_8443/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/459.GemsFDTD/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/531.deepsjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/bfs_cm2003/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/450.soplex/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/519.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/ycsb_abgsave/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/ycsb_aserver/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/447.dealII/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/tpch17/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/507.cactuBSSN/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/444.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/520.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/ycsb_bserver/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/435.gromacs/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/ycsb_eserver/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/557.xz/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/429.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/445.gobmk/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/jp2_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/526.blender/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/437.leslie3d/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/ycsb_cserver/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/483.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/471.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/462.libquantum/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/458.sjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/500.perlbench/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/525.x264/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/tpcc64/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/511.povray/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/401.bzip2/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/473.astar/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/538.imagick/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/bfs_ny/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/434.zeusmp/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/h264_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/436.cactusADM/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/508.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/481.wrf/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/433.milc/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/403.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/tpch6/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/wc_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/grep_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/470.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/544.nab/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/549.fotonik3d/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/482.sphinx3/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/505.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/bfs_dblp/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/jp2_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/h264_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/502.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/464.h264ref/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/tpch2/DDR4stats.stats
# Found stats file: ../../../verify-results/Baseline.yaml/456.hmmer/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/523.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/ycsb_dserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/510.parest/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/541.leela/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/wc_8443/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/459.GemsFDTD/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/531.deepsjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/bfs_cm2003/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/450.soplex/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/519.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/ycsb_abgsave/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/ycsb_aserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/447.dealII/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/tpch17/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/507.cactuBSSN/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/444.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/520.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/ycsb_bserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/435.gromacs/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/ycsb_eserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/557.xz/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/429.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/445.gobmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/jp2_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/526.blender/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/437.leslie3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/ycsb_cserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/483.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/471.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/462.libquantum/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/458.sjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/500.perlbench/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/525.x264/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/tpcc64/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/511.povray/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/401.bzip2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/473.astar/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/538.imagick/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/bfs_ny/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/434.zeusmp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/h264_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/436.cactusADM/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/508.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/481.wrf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/433.milc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/403.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/tpch6/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/wc_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/grep_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/470.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/544.nab/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/549.fotonik3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/482.sphinx3/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/505.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/bfs_dblp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/jp2_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/h264_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/502.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/464.h264ref/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/tpch2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-128-128.yaml/456.hmmer/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/523.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/ycsb_dserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/510.parest/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/541.leela/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/wc_8443/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/459.GemsFDTD/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/531.deepsjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/bfs_cm2003/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/450.soplex/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/519.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/ycsb_abgsave/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/ycsb_aserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/447.dealII/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/tpch17/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/507.cactuBSSN/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/444.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/520.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/ycsb_bserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/435.gromacs/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/ycsb_eserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/557.xz/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/429.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/445.gobmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/jp2_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/526.blender/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/437.leslie3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/ycsb_cserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/483.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/471.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/462.libquantum/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/458.sjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/500.perlbench/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/525.x264/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/tpcc64/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/511.povray/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/401.bzip2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/473.astar/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/538.imagick/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/bfs_ny/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/434.zeusmp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/h264_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/436.cactusADM/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/508.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/481.wrf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/433.milc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/403.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/tpch6/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/wc_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/grep_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/470.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/544.nab/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/549.fotonik3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/482.sphinx3/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/505.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/bfs_dblp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/jp2_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/h264_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/502.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/464.h264ref/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/tpch2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-256-128.yaml/456.hmmer/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/523.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/ycsb_dserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/510.parest/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/541.leela/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/wc_8443/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/459.GemsFDTD/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/531.deepsjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/bfs_cm2003/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/450.soplex/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/519.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/ycsb_abgsave/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/ycsb_aserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/447.dealII/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/tpch17/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/507.cactuBSSN/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/444.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/520.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/ycsb_bserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/435.gromacs/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/ycsb_eserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/557.xz/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/429.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/445.gobmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/jp2_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/526.blender/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/437.leslie3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/ycsb_cserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/483.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/471.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/462.libquantum/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/458.sjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/500.perlbench/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/525.x264/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/tpcc64/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/511.povray/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/401.bzip2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/473.astar/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/538.imagick/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/bfs_ny/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/434.zeusmp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/h264_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/436.cactusADM/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/508.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/481.wrf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/433.milc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/403.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/tpch6/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/wc_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/grep_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/470.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/544.nab/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/549.fotonik3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/482.sphinx3/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/505.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/bfs_dblp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/jp2_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/h264_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/502.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/464.h264ref/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/tpch2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-512-128.yaml/456.hmmer/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/523.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/ycsb_dserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/510.parest/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/541.leela/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/wc_8443/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/459.GemsFDTD/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/531.deepsjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/bfs_cm2003/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/450.soplex/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/519.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/ycsb_abgsave/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/ycsb_aserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/447.dealII/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/tpch17/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/507.cactuBSSN/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/444.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/520.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/ycsb_bserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/435.gromacs/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/ycsb_eserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/557.xz/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/429.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/445.gobmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/jp2_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/526.blender/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/437.leslie3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/ycsb_cserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/483.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/471.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/462.libquantum/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/458.sjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/500.perlbench/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/525.x264/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/tpcc64/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/511.povray/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/401.bzip2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/473.astar/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/538.imagick/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/bfs_ny/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/434.zeusmp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/h264_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/436.cactusADM/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/508.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/481.wrf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/433.milc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/403.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/tpch6/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/wc_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/grep_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/470.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/544.nab/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/549.fotonik3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/482.sphinx3/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/505.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/bfs_dblp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/jp2_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/h264_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/502.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/464.h264ref/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/tpch2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-1024-128.yaml/456.hmmer/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/523.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/ycsb_dserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/510.parest/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/541.leela/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/wc_8443/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/459.GemsFDTD/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/531.deepsjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/bfs_cm2003/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/450.soplex/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/519.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/ycsb_abgsave/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/ycsb_aserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/447.dealII/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/tpch17/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/507.cactuBSSN/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/444.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/520.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/ycsb_bserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/435.gromacs/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/ycsb_eserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/557.xz/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/429.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/445.gobmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/jp2_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/526.blender/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/437.leslie3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/ycsb_cserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/483.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/471.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/462.libquantum/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/458.sjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/500.perlbench/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/525.x264/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/tpcc64/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/511.povray/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/401.bzip2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/473.astar/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/538.imagick/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/bfs_ny/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/434.zeusmp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/h264_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/436.cactusADM/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/508.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/481.wrf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/433.milc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/403.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/tpch6/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/wc_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/grep_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/470.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/544.nab/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/549.fotonik3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/482.sphinx3/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/505.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/bfs_dblp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/jp2_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/h264_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/502.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/464.h264ref/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/tpch2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-1-2048-128.yaml/456.hmmer/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/523.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/ycsb_dserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/510.parest/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/541.leela/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/wc_8443/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/459.GemsFDTD/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/531.deepsjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/bfs_cm2003/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/450.soplex/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/519.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/ycsb_abgsave/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/ycsb_aserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/447.dealII/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/tpch17/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/507.cactuBSSN/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/444.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/520.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/ycsb_bserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/435.gromacs/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/ycsb_eserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/557.xz/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/429.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/445.gobmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/jp2_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/526.blender/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/437.leslie3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/ycsb_cserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/483.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/471.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/462.libquantum/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/458.sjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/500.perlbench/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/525.x264/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/tpcc64/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/511.povray/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/401.bzip2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/473.astar/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/538.imagick/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/bfs_ny/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/434.zeusmp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/h264_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/436.cactusADM/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/508.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/481.wrf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/433.milc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/403.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/tpch6/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/wc_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/grep_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/470.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/544.nab/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/549.fotonik3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/482.sphinx3/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/505.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/bfs_dblp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/jp2_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/h264_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/502.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/464.h264ref/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/tpch2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-128-128.yaml/456.hmmer/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/523.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/ycsb_dserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/510.parest/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/541.leela/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/wc_8443/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/459.GemsFDTD/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/531.deepsjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/bfs_cm2003/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/450.soplex/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/519.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/ycsb_abgsave/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/ycsb_aserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/447.dealII/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/tpch17/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/507.cactuBSSN/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/444.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/520.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/ycsb_bserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/435.gromacs/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/ycsb_eserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/557.xz/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/429.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/445.gobmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/jp2_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/526.blender/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/437.leslie3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/ycsb_cserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/483.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/471.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/462.libquantum/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/458.sjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/500.perlbench/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/525.x264/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/tpcc64/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/511.povray/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/401.bzip2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/473.astar/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/538.imagick/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/bfs_ny/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/434.zeusmp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/h264_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/436.cactusADM/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/508.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/481.wrf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/433.milc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/403.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/tpch6/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/wc_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/grep_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/470.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/544.nab/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/549.fotonik3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/482.sphinx3/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/505.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/bfs_dblp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/jp2_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/h264_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/502.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/464.h264ref/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/tpch2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-256-128.yaml/456.hmmer/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/523.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/ycsb_dserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/510.parest/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/541.leela/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/wc_8443/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/459.GemsFDTD/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/531.deepsjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/bfs_cm2003/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/450.soplex/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/519.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/ycsb_abgsave/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/ycsb_aserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-2-512-128.yaml/447.dealII/DDR4stats.stats
# ...
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/526.blender/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/437.leslie3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/ycsb_cserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/483.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/471.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/462.libquantum/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/458.sjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/500.perlbench/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/525.x264/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/tpcc64/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/511.povray/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/401.bzip2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/473.astar/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/538.imagick/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/bfs_ny/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/434.zeusmp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/h264_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/436.cactusADM/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/508.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/481.wrf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/433.milc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/403.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/tpch6/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/wc_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/grep_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/470.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/544.nab/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/549.fotonik3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/482.sphinx3/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/505.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/bfs_dblp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/jp2_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/h264_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/502.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/464.h264ref/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/tpch2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-512-128.yaml/456.hmmer/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/523.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/ycsb_dserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/510.parest/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/541.leela/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/wc_8443/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/459.GemsFDTD/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/531.deepsjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/bfs_cm2003/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/450.soplex/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/519.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/ycsb_abgsave/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/ycsb_aserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/447.dealII/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/tpch17/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/507.cactuBSSN/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/444.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/520.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/ycsb_bserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/435.gromacs/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/ycsb_eserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/557.xz/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/429.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/445.gobmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/jp2_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/526.blender/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/437.leslie3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/ycsb_cserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/483.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/471.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/462.libquantum/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/458.sjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/500.perlbench/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/525.x264/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/tpcc64/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/511.povray/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/401.bzip2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/473.astar/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/538.imagick/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/bfs_ny/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/434.zeusmp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/h264_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/436.cactusADM/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/508.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/481.wrf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/433.milc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/403.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/tpch6/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/wc_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/grep_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/470.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/544.nab/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/549.fotonik3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/482.sphinx3/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/505.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/bfs_dblp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/jp2_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/h264_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/502.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/464.h264ref/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/tpch2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-1024-128.yaml/456.hmmer/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/523.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/ycsb_dserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/510.parest/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/541.leela/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/wc_8443/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/459.GemsFDTD/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/531.deepsjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/bfs_cm2003/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/450.soplex/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/519.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/ycsb_abgsave/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/ycsb_aserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/447.dealII/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/tpch17/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/507.cactuBSSN/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/444.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/520.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/ycsb_bserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/435.gromacs/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/ycsb_eserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/557.xz/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/429.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/445.gobmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/jp2_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/526.blender/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/437.leslie3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/ycsb_cserver/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/483.xalancbmk/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/471.omnetpp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/462.libquantum/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/458.sjeng/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/500.perlbench/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/525.x264/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/tpcc64/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/511.povray/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/401.bzip2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/473.astar/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/538.imagick/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/bfs_ny/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/434.zeusmp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/h264_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/436.cactusADM/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/508.namd/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/481.wrf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/433.milc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/403.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/tpch6/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/wc_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/grep_map0/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/470.lbm/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/544.nab/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/549.fotonik3d/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/482.sphinx3/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/505.mcf/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/bfs_dblp/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/jp2_decode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/h264_encode/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/502.gcc/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/464.h264ref/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/tpch2/DDR4stats.stats
# Found stats file: ../../../verify-results/CoMeT1000-16-2048-128.yaml/456.hmmer/DDR4stats.stats
# ['523.xalancbmk' 'ycsb_dserver' '510.parest' '541.leela' 'wc_8443'
#  '459.GemsFDTD' '531.deepsjeng' 'bfs_cm2003' '450.soplex' '519.lbm'
#  'ycsb_abgsave' 'ycsb_aserver' '447.dealII' 'tpch17' '507.cactuBSSN'
#  '444.namd' '520.omnetpp' 'ycsb_bserver' '435.gromacs' 'ycsb_eserver'
#  '557.xz' '429.mcf' '445.gobmk' 'jp2_encode' '526.blender' '437.leslie3d'
#  'ycsb_cserver' '483.xalancbmk' '471.omnetpp' '462.libquantum' '458.sjeng'
#  '500.perlbench' '525.x264' 'tpcc64' '511.povray' '401.bzip2' '473.astar'
#  '538.imagick' 'bfs_ny' '434.zeusmp' 'h264_decode' '436.cactusADM'
#  '508.namd' '481.wrf' '433.milc' '403.gcc' 'tpch6' 'wc_map0' 'grep_map0'
#  '470.lbm' '544.nab' '549.fotonik3d' '482.sphinx3' '505.mcf' 'bfs_dblp'
#  'jp2_decode' 'h264_encode' '502.gcc' '464.h264ref' 'tpch2' '456.hmmer']

# %%
# use seaborn-deep style
sns.set(font_scale=1.0)
sns.set_style("whitegrid")
sns.set_palette("pastel", n_colors=4)

stats = stats_copy.copy()



# instructions per cycle (IPC) is record_cycles_insts_0 / record_cycs_core_0
stats['ramulator.ipc'] = stats['ramulator.record_insts_core_0'] / stats['ramulator.record_cycs_core_0']


stats['ramulator.rbmpki'] = (stats['ramulator.row_conflicts_channel_0_core'] + stats['ramulator.row_misses_channel_0_core']) /\
                            stats['ramulator.record_insts_core_0'] * 1000


# copy the IPC of the baseline config as to all configs
baseline = stats[stats['config'] == 'Baseline0']
baseline = baseline[['workload', 'ramulator.ipc', 'ramulator.read_latency_avg_0', 'ramulator.rbmpki', 'ramulator.window_full_stall_cycles_core_0']]
# baseline
baseline.columns = ['workload', 'ramulator.baseline_ipc', 'ramulator.baseline_read_latency_avg_0', 'ramulator.baseline_rbmpki', 'ramulator.baseline_stall_cycles']
print('baseline:')
print(baseline)

stats = pd.merge(stats, baseline, on='workload')


#hydra baseline
# hydra_baseline = stats[stats['config'] == 'Hydra-Baseline']
# hydra_baseline = hydra_baseline[['workload', 'ramulator.ipc']]
# # hydra_baseline
# hydra_baseline.columns = ['workload', 'ramulator.hydra_baseline_ipc']
# stats = pd.merge(stats, hydra_baseline, on='workload')

stats['ramulator.normalized_ipc'] = stats['ramulator.ipc'] / stats['ramulator.baseline_ipc']
stats['ramulator.normalized_read_latency'] = stats['ramulator.read_latency_avg_0'] / stats['ramulator.baseline_read_latency_avg_0']
stats['ramulator.normalized_stall_cycles'] = stats['ramulator.window_full_stall_cycles_core_0'] / stats['ramulator.baseline_stall_cycles']
stats['ramulator.normalized_rbmpki'] = stats['ramulator.rbmpki'] / stats['ramulator.baseline_rbmpki']


# normalized ipc for hydra is not correct, so we overwrite it with the correct value
# stats.loc[stats['config'].str.contains('Hydra'), 'ramulator.normalized_ipc'] = stats['ramulator.ipc'] / stats['ramulator.hydra_baseline_ipc']

# add the geometric normalized ipc average as a new workload to every config
geometric_mean = stats.groupby(['config','nrh'])['ramulator.normalized_ipc'].apply(lambda x: x.prod()**(1.0/len(x))).reset_index()
geometric_mean['workload'] = 'GeoMean'

#print(stats['config'])


stats = pd.concat([stats, geometric_mean])
print(stats['config'])
print(stats['workload'])
# Out:
# baseline:
#          workload ramulator.baseline_ipc  \
# 0   523.xalancbmk               2.923912
# 0    ycsb_dserver               2.373734
# 0      510.parest               2.842678
# 0       541.leela               3.705667
# 0         wc_8443               2.045795
# ..            ...                    ...
# 0     h264_encode               3.998659
# 0         502.gcc               3.124588
# 0     464.h264ref               3.792771
# 0           tpch2               1.525505
# 0       456.hmmer               3.733412
#
#    ramulator.baseline_read_latency_avg_0 ramulator.baseline_rbmpki  \
# 0                              44.029382                   0.17985
# 0                              65.054207                  1.236015
# 0                              36.718865                   0.03407
# 0                              62.813485                   0.00444
# 0                              75.895156                   4.25492
# ..                                   ...                       ...
# 0                             106.888889                  0.000135
# 0                              62.440113                  0.163645
# 0                              55.326417                  0.018265
# 0                              76.756783                   8.70407
# 0                              48.718449                  0.007645
#
#    ramulator.baseline_stall_cycles
# 0                       16479610.0
# 0                       33820971.0
# 0                       18911192.0
# 0                        3875704.0
# 0                       47396285.0
# ..                             ...
# 0                          16218.0
# 0                       13100937.0
# 0                        2659420.0
# 0                       79298716.0
# 0                        3250654.0
#
# [61 rows x 5 columns]
# 0                Baseline0
# 1      CoMeT1000-1-128-128
# 2      CoMeT1000-1-256-128
# 3      CoMeT1000-1-512-128
# 4     CoMeT1000-1-1024-128
#               ...
# 21    CoMeT1000-8-1024-128
# 22     CoMeT1000-8-128-128
# 23    CoMeT1000-8-2048-128
# 24     CoMeT1000-8-256-128
# 25     CoMeT1000-8-512-128
# Name: config, Length: 1612, dtype: object
# 0     523.xalancbmk
# 1     523.xalancbmk
# 2     523.xalancbmk
# 3     523.xalancbmk
# 4     523.xalancbmk
#           ...
# 21          GeoMean
# 22          GeoMean
# 23          GeoMean
# 24          GeoMean
# 25          GeoMean
# Name: workload, Length: 1612, dtype: object

# %%
stats_clean = stats.copy()

# %%
import re

stats_sweep = stats_clean.copy()
sns.set(font_scale=1.0)
sns.set_style("whitegrid")
#sns.set_palette("viridis", n_colors=5)

# sns set color palette
comet_palette = ['#648FFF', '#785EF0', '#DC267F', '#FE6100', '#FFB000']
sns.set_palette(comet_palette, n_colors=5)

#print(stats_sweep['config'].unique())
# new dataframe that does not have the baseline configs
stats_no_baseline = stats_sweep[~stats_sweep['config'].str.contains('Baseline0')]
# keep only the configs that have CMS in the name
stats_sweep = stats_sweep[stats_sweep['config'].str.contains('CoMeT')]

stats_no_baseline['counters'] = stats_no_baseline['config'].apply(lambda x: int(re.search(r'CoMeT1000-\d+-(\d+)-\d+', x).group(1)) if re.search(r'CoMeT1000-\d+-(\d+)-\d+', x) else 0)
stats_no_baseline['hashes'] = stats_no_baseline['config'].apply(lambda x: int(re.search(r'CoMeT1000-(\d+)-\d+-\d+', x).group(1)) if re.search(r'CoMeT1000-(\d+)-\d+-\d+', x) else 0)

# order nRH from high to low
stats_no_baseline['counters'] = pd.Categorical(stats_no_baseline['counters'], categories=[128,256,512,1024,2048], ordered=True)

stats_no_baseline['hashes'] = pd.Categorical(stats_no_baseline['hashes'], categories=[1,2,4,8,16], ordered=True)

# drop entries with empty config
stats_no_baseline = stats_no_baseline[stats_no_baseline['config'].notna()]

#boxplot of normalized IPC
fig, ax = plt.subplots(figsize=(10, 3.6))
# show mean values as well
ax = sns.boxplot(x="hashes", y="ramulator.normalized_ipc", hue="counters", data=stats_no_baseline, showmeans=True, 
                 meanprops={"marker":"o","markerfacecolor":"white", "markeredgecolor":"black"}, showfliers=True, 
                 flierprops={'marker': 'x', 'markerfacecolor': 'black', 'markeredgecolor': 'black'})
ax.set_xlabel('Number of Hash Functions ($N_{Hash}$)')
ax.set_ylabel('Normalized\nIPC Distribution')
# draw a red line at y = 1.0, label it as baseline IPC
ax.axhline(y=1.0, color='r', linestyle='--')
# write above the red line 'baseline IPC'
#ax.text(0.02, 0.91, 'baseline IPC', color='#e74c3c', transform=ax.transAxes, fontsize=15)
# extend the y axis to 1.2
ax.set_ylim(0, 1.2)
# color the 5th y tick red
ax.get_yticklabels()[5].set_color('#e74c3c')
# make axis tick font bigger
ax.tick_params(axis='both', which='major', labelsize=14)
# draw vertical lines to separate the rowhammer threshold values
ax.axvline(x=0.5, color='grey', linestyle='-', alpha=0.5)
ax.axvline(x=1.5, color='grey', linestyle='-', alpha=0.5)
ax.axvline(x=2.5, color='grey', linestyle='-', alpha=0.5)
ax.axvline(x=3.5, color='grey', linestyle='-', alpha=0.5)
ax.axvline(x=4.5, color='grey', linestyle='-', alpha=0.5)
# make x and y axis labels bigger
ax.xaxis.label.set_size(16)
ax.yaxis.label.set_size(16)

# Customize the whiskers and borders
ax.lines[0].set_color('black')  # Set the color of the whiskers\

# put the legend on top of the plot
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=5, fancybox=True, shadow=True, fontsize=12)
# add legend title as "counters per hash"
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=20, fancybox=False, shadow=False, fontsize=12, title_fontsize=12, title='Counters per Hash Function ($N_{Counters}$)', framealpha=1)

plt.tight_layout()
plt.show()

# save figure
fig.savefig('cometsweep1k.pdf', bbox_inches='tight')
# export data to csv
stats_no_baseline.to_csv('cometsweep1k.csv', index=False)

# list mean normalized_ipc at 1000 nRH for all configs

# %%
# print the number of workloads per config
print(stats_no_baseline.groupby(['config'])['workload'].count())
# Out:
# config
# CoMeT1000-1-1024-128     62
# CoMeT1000-1-128-128      62
# CoMeT1000-1-2048-128     62
# CoMeT1000-1-256-128      62
# CoMeT1000-1-512-128      62
# CoMeT1000-16-1024-128    62
# CoMeT1000-16-128-128     62
# CoMeT1000-16-2048-128    62
# CoMeT1000-16-256-128     62
# CoMeT1000-16-512-128     62
# CoMeT1000-2-1024-128     62
# CoMeT1000-2-128-128      62
# CoMeT1000-2-2048-128     62
# CoMeT1000-2-256-128      62
# CoMeT1000-2-512-128      62
# CoMeT1000-4-1024-128     62
# CoMeT1000-4-128-128      62
# CoMeT1000-4-2048-128     62
# CoMeT1000-4-256-128      62
# CoMeT1000-4-512-128      62
# CoMeT1000-8-1024-128     62
# CoMeT1000-8-128-128      62
# CoMeT1000-8-2048-128     62
# CoMeT1000-8-256-128      62
# CoMeT1000-8-512-128      62
# Name: workload, dtype: int64
